# %% [markdown]
# # Actividad — Comparar el clima entre varias ciudades con Open-Meteo (Sesión 8)
#
# En el Bloque 2 consultaste el pronóstico por hora de Ciudad Juárez con Open-Meteo. En esta actividad usas
# la misma API, pero de otra forma: en vez de un pronóstico por hora de una sola ciudad, se consulta el
# **clima actual** de **varias ciudades distintas** y se construye una tabla comparativa.
#
# **Endpoint:** `https://api.open-meteo.com/v1/forecast`
# **Parámetro clave:** `current_weather=true` — regresa un solo valor actual (no una lista por hora) dentro
# de `datos["current_weather"]`, con `temperature`, `windspeed`, `weathercode` y `time`.
#
# **Instrucciones:**
#
# 1. Define una lista `ciudades` con al menos tres ciudades (nombre, latitud, longitud), distintas a
#    Ciudad Juárez.
# 2. Para cada ciudad, consulta el endpoint con `current_weather=true`, usando `timeout` y manejo de
#    errores como en el Bloque 2.
# 3. De cada respuesta, extrae la temperatura y la velocidad del viento actuales.
# 4. Estructura la información como una lista de diccionarios llamada `info_clima`.
# 5. Convierte `info_clima` en un DataFrame llamado `df_clima_ciudades`.
# 6. Verifica el resultado.

# %% [markdown]
# **Paso 1 — Define las ciudades a consultar.**

# %%
ciudades = [
    {"nombre": "New York", "latitud": 40.71, "longitud": 74},
    {"nombre": "Tokyo", "latitud": 35.68, "longitud": 139.69},
    {"nombre": "Barcelona", "latitud": 41.38, "longitud": 2.17},
    {"nombre": "Buenos Aires", "latitud": -34.61, "longitud": -58.38},
    {"nombre": "Sydney", "latitud": -33.86, "longitud": 151.21},
    {"nombre": "Rio de Janeiro", "latitud": -22.9, "longitud": -43.22},
    {"nombre": "Mexico City", "latitud": 19.43, "longitud": -99.13},
    {"nombre": "Santiago", "latitud": -33.45, "longitud": -70.66},
    {"nombre": "Sao Paulo", "latitud": -23.55, "longitud": -46.63},
]  # puedes cambiar o agregar ciudades

# %% [markdown]
# **Pasos 2 a 4 — Consultar cada ciudad y estructurar la información.**

# %%
import requests

info_clima = []

for ciudad in ciudades:
    endpoint = "https://api.open-meteo.com/v1/forecast"
    parametros = {
        "latitude": ciudad["latitud"],
        "longitude": ciudad["longitud"],
        "current_weather": True,
    }

    # Completa: envía la solicitud con timeout, revisa status_code con raise_for_status()
    try:
        respuesta = requests.get(endpoint, params=parametros, timeout=30)
        print(f'{ciudad['nombre']}, Status code: {respuesta.status_code}')
        respuesta.raise_for_status()
        datos = respuesta.json()
        clima_actual = datos["current_weather"]


        # Completa: extrae temperature y windspeed de clima_actual
        info_clima.append({
            "ciudad": ciudad["nombre"],
            "temperatura":  datos['current_weather']['temperature'],
            "viento": datos['current_weather']['windspeed'],
        })

    except requests.RequestException as error:
        print(f"No fue posible consultar {ciudad['nombre']}:", error)

info_clima
# Out:
# New York, Status code: 200
# Tokyo, Status code: 200
# Barcelona, Status code: 200
# Buenos Aires, Status code: 200
# Sydney, Status code: 200
# Rio de Janeiro, Status code: 200
# Mexico City, Status code: 200
# Santiago, Status code: 200
# Sao Paulo, Status code: 200
# [{'ciudad': 'New York', 'temperatura': 1.1, 'viento': 4.0},
#  {'ciudad': 'Tokyo', 'temperatura': 24.3, 'viento': 3.0},
#  {'ciudad': 'Barcelona', 'temperatura': 25.8, 'viento': 2.4},
#  {'ciudad': 'Buenos Aires', 'temperatura': 22.5, 'viento': 16.7},
#  {'ciudad': 'Sydney', 'temperatura': 18.0, 'viento': 14.0},
#  {'ciudad': 'Rio de Janeiro', 'temperatura': 21.6, 'viento': 9.0},
#  {'ciudad': 'Mexico City', 'temperatura': 23.2, 'viento': 5.8},
#  {'ciudad': 'Santiago', 'temperatura': 19.2, 'viento': 12.0},
#  {'ciudad': 'Sao Paulo', 'temperatura': 18.7, 'viento': 11.6}]

# %% [markdown]
# **Paso 5 — Construir el DataFrame.**

# %%
# Completa: convierte info_clima en un DataFrame llamado df_clima_ciudades
import pandas as pd
df_clima_ciudades = pd.DataFrame(info_clima)
df_clima_ciudades
# Out:
#            ciudad  temperatura  viento
# 0        New York          1.0     4.2
# 1           Tokyo         24.3     3.1
# 2       Barcelona         26.1     2.5
# 3    Buenos Aires         22.6    16.7
# 4          Sydney         18.1    15.1
# 5  Rio de Janeiro         21.7     9.4
# 6     Mexico City         23.1     5.8
# 7        Santiago         19.4    12.2
# 8       Sao Paulo         19.1    11.5

# %% [markdown]
# **Paso 6 — Verificar el resultado.**

# %%
# Completa: imprime shape, columns y valores faltantes de df_clima_ciudades

print("Dimensiones:", df_clima_ciudades.shape)
print()
df_clima_ciudades.info()
print()
print("Valores faltantes por columna:")
print(df_clima_ciudades.isna().sum())
# Out:
# Dimensiones: (9, 3)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ciudad       9 non-null      object
#  1   temperatura  9 non-null      float64
#  2   viento       9 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 348.0+ bytes
#
# Valores faltantes por columna:
# ciudad         0
# temperatura    0
# viento         0
# dtype: int64
